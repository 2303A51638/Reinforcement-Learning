# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51638/Reinforcement-Learning/blob/main/RL_assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

machines = ['A', 'B', 'C']

M = 3

N_play = 10

N = [0, 0, 0]
R = [0, 0, 0]
Q = [0, 0, 0]
UCB = [0, 0, 0]

total_reward = 0


for play in range(1, N_play + 1):


    if play <= M:
        selected = play - 1
    else:

        for i in range(M):
            UCB[i] = Q[i] + math.sqrt((2 * math.log(play)) / N[i])

        selected = UCB.index(max(UCB))

    print("\nPlay", play)
    print("Selected Machine:", machines[selected])

    reward = float(input("Enter reward: "))

    N[selected] += 1

    R[selected] += reward
    total_reward += reward

    Q[selected] = Q[selected] + (reward - Q[selected]) / N[selected]

    print("N =", N)
    print("R =", R)
    print("Q =", [round(x, 2) for x in Q])


print("\n========== FINAL RESULTS ==========")

print("\nMachine\tN\tR\tUCB\tQ")


for i in range(M):
    if N[i] > 0:
        UCB[i] = Q[i] + math.sqrt((2 * math.log(N_play)) / N[i])
    else:
        UCB[i] = float('inf')

for i in range(M):
    print(machines[i], "\t", N[i], "\t", R[i],
          "\t", round(UCB[i], 2),
          "\t", round(Q[i], 2))

print("\nTotal Reward =", total_reward)
# Out:
# Play 1
# Selected Machine: A
# Enter reward: 3
# N = [1, 0, 0]
# R = [3.0, 0, 0]
# Q = [3.0, 0, 0]
#
# Play 2
# Selected Machine: B
# Enter reward: 6
# N = [1, 1, 0]
# R = [3.0, 6.0, 0]
# Q = [3.0, 6.0, 0]
#
# Play 3
# Selected Machine: C
# Enter reward: 4
# N = [1, 1, 1]
# R = [3.0, 6.0, 4.0]
# Q = [3.0, 6.0, 4.0]
#
# Play 4
# Selected Machine: B
# Enter reward: 4
# N = [1, 2, 1]
# R = [3.0, 10.0, 4.0]
# Q = [3.0, 5.0, 4.0]
#
# Play 5
# Selected Machine: B
# Enter reward: 7
# N = [1, 3, 1]
# R = [3.0, 17.0, 4.0]
# Q = [3.0, 5.67, 4.0]
#
# Play 6
# Selected Machine: B
# Enter reward: 3
# N = [1, 4, 1]
# R = [3.0, 20.0, 4.0]
# Q = [3.0, 5.0, 4.0]
#
# Play 7
# Selected Machine: B
# Enter reward: 2
# N = [1, 5, 1]
# R = [3.0, 22.0, 4.0]
# Q = [3.0, 4.4, 4.0]
#
# Play 8
# Selected Machine: C
# Enter reward: 5
# N = [1, 5, 2]
# R = [3.0, 22.0, 9.0]
# Q = [3.0, 4.4, 4.5]
#
# Play 9
# Selected Machine: C
# Enter reward: 5
# N = [1, 5, 3]
# R = [3.0, 22.0, 14.0]
# Q = [3.0, 4.4, 4.67]
#
# ...
