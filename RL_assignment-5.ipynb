# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51638/Reinforcement-Learning/blob/main/RL_assignment-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def run_random_agent(env_name, episodes=10):
    env = gym.make(env_name)

    total_rewards = []

    for episode in range(episodes):
        state, info = env.reset()
        done = False
        total_reward = 0

        while not done:
            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            state = next_state

            done = terminated or truncated

        total_rewards.append(total_reward)

        print(f"Episode {episode + 1}: Total Reward = {total_reward}")

    average_reward = sum(total_rewards) / episodes

    print("\nEnvironment:", env_name)
    print("Total Reward:", sum(total_rewards))
    print("Average Reward:", average_reward)

    env.close()


print("===== CARTPOLE =====")
run_random_agent("CartPole-v1")

print("\n===== MOUNTAINCAR =====")
run_random_agent("MountainCar-v0")

print("\n===== FROZENLAKE =====")
run_random_agent("FrozenLake-v1")
# Out:
# ===== CARTPOLE =====
# Episode 1: Total Reward = 22.0
# Episode 2: Total Reward = 30.0
# Episode 3: Total Reward = 9.0
# Episode 4: Total Reward = 24.0
# Episode 5: Total Reward = 27.0
# Episode 6: Total Reward = 30.0
# Episode 7: Total Reward = 18.0
# Episode 8: Total Reward = 33.0
# Episode 9: Total Reward = 24.0
# Episode 10: Total Reward = 29.0
#
# Environment: CartPole-v1
# Total Reward: 246.0
# Average Reward: 24.6
#
# ===== MOUNTAINCAR =====
# Episode 1: Total Reward = -200.0
# Episode 2: Total Reward = -200.0
# Episode 3: Total Reward = -200.0
# Episode 4: Total Reward = -200.0
# Episode 5: Total Reward = -200.0
# Episode 6: Total Reward = -200.0
# Episode 7: Total Reward = -200.0
# Episode 8: Total Reward = -200.0
# Episode 9: Total Reward = -200.0
# Episode 10: Total Reward = -200.0
#
# Environment: MountainCar-v0
# Total Reward: -2000.0
# Average Reward: -200.0
#
# ===== FROZENLAKE =====
# Episode 1: Total Reward = 0
# Episode 2: Total Reward = 0
# ...
