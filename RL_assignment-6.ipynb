# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51638/Reinforcement-Learning/blob/main/RL_assignment-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    rewards = []

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0

        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()

            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            state = next_state
            steps += 1

        rewards.append(total_reward)

        print(f"Episode {episode}: Total Reward = {total_reward}, Steps = {steps}")

    average_reward = sum(rewards) / len(rewards)

    print("\nAverage Reward =", average_reward)

    env.close()


print("----- CliffWalking -----")
random_agent("CliffWalking-v1", 5)

print("\n----- Taxi -----")
random_agent("Taxi-v4", 5)
# Out:
# ----- CliffWalking -----
# Episode 1: Total Reward = -7325, Steps = 791
# Episode 2: Total Reward = -29254, Steps = 3415
# Episode 3: Total Reward = -47846, Steps = 4385
# Episode 4: Total Reward = -11996, Steps = 1502
# Episode 5: Total Reward = -44457, Steps = 4263
#
# Average Reward = -28175.6
#
# ----- Taxi -----
# Episode 1: Total Reward = -848, Steps = 200
# Episode 2: Total Reward = -830, Steps = 200
# Episode 3: Total Reward = -713, Steps = 200
# Episode 4: Total Reward = -803, Steps = 200
# Episode 5: Total Reward = -686, Steps = 200
#
# Average Reward = -776.0
